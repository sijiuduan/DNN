# %%
import sys
sys.path.append("../../")
from jnn.ea import Ea
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
img1 = Image.open('org.jpg')
img2 = Image.open('cur.jpg')

plt.figure(num='astronaut',figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(img1)

plt.subplot(1,2,2)
plt.imshow(img2)
plt.show()

# %%
p1p2 = Ea.load("p1p2.pkl")
print(p1p2.shape)
print(p1p2)
p = np.unique(p1p2,axis=0)
p
# Out:
# (73, 4)
# [[ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
#  [ 586.          434.          527.          369.        ]
# ...
